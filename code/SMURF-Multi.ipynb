# %%
import os
import pandas as pd
import numpy as np
import scipy
from sklearn.cross_validation import StratifiedKFold
from sklearn.cross_validation import cross_val_predict
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC
from sklearn import preprocessing
from sklearn.utils import shuffle
from sklearn import metrics
import time
# Out:
# C:\Users\SungJoonPark\Anaconda2\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
sparse_matrix = scipy.sparse.load_npz('../data/TCGA/npz/TCGA_nofiltering.npz')
feature_array = np.array(pd.read_csv("../data/TCGA/npz/features.txt",header=None)[0].tolist())
print(sparse_matrix.shape)
feature_index = np.where(sparse_matrix.sum(axis=0)>4)[1]
sparse_matrix_temp = sparse_matrix[:,feature_index]
print(sparse_matrix_temp.shape)
sample_index = np.where(sparse_matrix_temp.sum(axis=1)!=0)[0]
sparse_matrix_temp = sparse_matrix_temp[sample_index,:]
print(sparse_matrix_temp.shape)


X = sparse_matrix_temp

feature_array = feature_array[feature_index]
print(feature_array.shape)



label_array = np.array(pd.read_csv("../data/TCGA/npz/labels.txt",header=None)[0].tolist())
label_array = label_array[sample_index]
le = preprocessing.LabelEncoder()
le.fit(label_array)
y = le.transform(label_array)
print(y.shape)

X, y = shuffle(X, y, random_state=0)
# Out:
# (9822, 1700753)
# (9822, 5696)
# (8342, 5696)
# (5696L,)
# (8342L,)

# %%
clf_list = [KNeighborsClassifier(n_neighbors =5,algorithm='auto'),
            LogisticRegression(penalty='l2',multi_class='multinomial',solver='lbfgs'),
            LinearSVC(penalty='l2', multi_class='crammer_singer',dual=False),
            RandomForestClassifier(n_estimators=500),
            GradientBoostingClassifier(n_estimators=500),
            ExtraTreesClassifier(n_estimators=500),
            MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(10, 20), random_state=1)]

# %%
for clf in clf_list:
    print(clf)
    start_t = time.time()

    cv_preds = cross_val_predict(clf, X, y, cv=10)
    print("Accuracy : ",metrics.accuracy_score(cv_preds,y))
    print("F1-Micro : ",metrics.f1_score(cv_preds,y,average='micro'))
    print("F1-Macro : ",metrics.f1_score(cv_preds,y,average='macro'))
    print("F1-Weighted : ",metrics.f1_score(cv_preds,y,average='weighted'))

    end_t = time.time()
    print(str((end_t-start_t)/60.0)+" minutes elapsed")
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='multinomial',
#           n_jobs=1, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)
# C:\Users\SungJoonPark\Anaconda3\lib\site-packages\sklearn\cross_validation.py:553: Warning: The least populated class in y has only 9 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=10.
#   % (min_labels, self.n_folds)), Warning)
# Accuracy :  0.46877637130801686
# F1-Micro :  0.46877637130801686
# F1-Macro :  0.28106630388765824
# F1-Weighted :  0.514000618469542
# 0.1253614862759908 minutes elapsed
# C:\Users\SungJoonPark\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %% [markdown]
# ### Multi-class Feature Selection

# %%
skf = StratifiedKFold(y,n_folds=10,shuffle=True)
topk_list = [100,152,200,280,300,400,500,600,700,800,900,1000,1100,1200]

cv_preds_list =[]
cv_y_list =[]
for topk in topk_list:
    print(topk)
    cv_y = []
    cv_preds = []
    for train_index, test_index in skf:
        X_train, X_test = X[train_index,:], X[test_index,:]
        y_train, y_test = y[train_index], y[test_index]

        clf=LinearSVC(penalty='l2', multi_class='crammer_singer',dual=False) 
        clf.fit(X_train,y_train)
        coef_ = clf.coef_
        coef_ = np.abs(coef_)
        coef_ = coef_.mean(axis=0)
        fis = pd.Series(coef_,index=feature_array)

                
        fis = fis[fis>0]    
        fis = fis.sort_values(ascending=False)
        fis_topk_list = fis.index.tolist()[0:topk]
        fis_topk_list_index = np.isin(feature_array,fis_topk_list)
        

        clf = LogisticRegression(penalty='l2',multi_class='multinomial',solver='lbfgs')

        X_train = X_train[:,fis_topk_list_index]
        X_test = X_test[:, fis_topk_list_index]        
        
        clf.fit(X_train,y_train)
        pred = clf.predict(X_test).tolist()
        cv_preds.extend(pred)
        cv_y.extend(y_test.tolist())
    
    cv_preds_list.append(cv_preds)
    cv_y_list.append(cv_y)
# Out:
# 100
# ('X_train shape', (7492, 100))
# ('X_test shape', (850, 100))
# ('X_train shape', (7496, 100))
# ('X_test shape', (846, 100))
# ('X_train shape', (7497, 100))
# ('X_test shape', (845, 100))
# ('X_train shape', (7506, 100))
# ('X_test shape', (836, 100))
# ('X_train shape', (7508, 100))
# ('X_test shape', (834, 100))
# ('X_train shape', (7510, 100))
# ('X_test shape', (832, 100))
# ('X_train shape', (7514, 100))
# ('X_test shape', (828, 100))
# ('X_train shape', (7516, 100))
# ('X_test shape', (826, 100))
# ('X_train shape', (7518, 100))
# ('X_test shape', (824, 100))
# ('X_train shape', (7521, 100))
# ('X_test shape', (821, 100))
# 152
# ('X_train shape', (7492, 152))
# ('X_test shape', (850, 152))
# ('X_train shape', (7496, 152))
# ('X_test shape', (846, 152))
# ('X_train shape', (7497, 152))
# ('X_test shape', (845, 152))
# ('X_train shape', (7506, 152))
# ('X_test shape', (836, 152))
# ('X_train shape', (7508, 152))
# ('X_test shape', (834, 152))
# ('X_train shape', (7510, 152))
# ('X_test shape', (832, 152))
# ('X_train shape', (7514, 152))
# ('X_test shape', (828, 152))
# ('X_train shape', (7516, 152))
# ('X_test shape', (826, 152))
# ('X_train shape', (7518, 152))
# ('X_test shape', (824, 152))
# ('X_train shape', (7521, 152))
# ('X_test shape', (821, 152))
# 200
# ('X_train shape', (7492, 200))
# ('X_test shape', (850, 200))
# ('X_train shape', (7496, 200))
# ('X_test shape', (846, 200))
# ('X_train shape', (7497, 200))
# ('X_test shape', (845, 200))
# ('X_train shape', (7506, 200))
# ('X_test shape', (836, 200))
# ('X_train shape', (7508, 200))
# ('X_test shape', (834, 200))
# ('X_train shape', (7510, 200))
# ('X_test shape', (832, 200))
# ('X_train shape', (7514, 200))
# ('X_test shape', (828, 200))
# ('X_train shape', (7516, 200))
# ('X_test shape', (826, 200))
# ('X_train shape', (7518, 200))
# ('X_test shape', (824, 200))
# ('X_train shape', (7521, 200))
# ('X_test shape', (821, 200))
# 280
# ('X_train shape', (7492, 280))
# ('X_test shape', (850, 280))
# ('X_train shape', (7496, 280))
# ('X_test shape', (846, 280))
# ('X_train shape', (7497, 280))
# ('X_test shape', (845, 280))
# ('X_train shape', (7506, 280))
# ('X_test shape', (836, 280))
# ('X_train shape', (7508, 280))
# ('X_test shape', (834, 280))
# ('X_train shape', (7510, 280))
# ('X_test shape', (832, 280))
# ('X_train shape', (7514, 280))
# ('X_test shape', (828, 280))
# ('X_train shape', (7516, 280))
# ('X_test shape', (826, 280))
# ('X_train shape', (7518, 280))
# ('X_test shape', (824, 280))
# ('X_train shape', (7521, 280))
# ('X_test shape', (821, 280))
# 300
# ('X_train shape', (7492, 300))
# ('X_test shape', (850, 300))
# ('X_train shape', (7496, 300))
# ('X_test shape', (846, 300))
# ('X_train shape', (7497, 300))
# ('X_test shape', (845, 300))
# ('X_train shape', (7506, 300))
# ('X_test shape', (836, 300))
# ('X_train shape', (7508, 300))
# ('X_test shape', (834, 300))
# ('X_train shape', (7510, 300))
# ('X_test shape', (832, 300))
# ('X_train shape', (7514, 300))
# ('X_test shape', (828, 300))
# ('X_train shape', (7516, 300))
# ('X_test shape', (826, 300))
# ('X_train shape', (7518, 300))
# ('X_test shape', (824, 300))
# ('X_train shape', (7521, 300))
# ('X_test shape', (821, 300))
# 400
# ('X_train shape', (7492, 400))
# ('X_test shape', (850, 400))
# ('X_train shape', (7496, 400))
# ('X_test shape', (846, 400))
# ('X_train shape', (7497, 400))
# ('X_test shape', (845, 400))
# ('X_train shape', (7506, 400))
# ('X_test shape', (836, 400))
# ('X_train shape', (7508, 400))
# ('X_test shape', (834, 400))
# ('X_train shape', (7510, 400))
# ('X_test shape', (832, 400))
# ('X_train shape', (7514, 400))
# ('X_test shape', (828, 400))
# ('X_train shape', (7516, 400))
# ('X_test shape', (826, 400))
# ('X_train shape', (7518, 400))
# ('X_test shape', (824, 400))
# ('X_train shape', (7521, 400))
# ('X_test shape', (821, 400))
# 500
# ('X_train shape', (7492, 500))
# ('X_test shape', (850, 500))
# ('X_train shape', (7496, 500))
# ('X_test shape', (846, 500))
# ('X_train shape', (7497, 500))
# ('X_test shape', (845, 500))
# ('X_train shape', (7506, 500))
# ('X_test shape', (836, 500))
# ('X_train shape', (7508, 500))
# ('X_test shape', (834, 500))
# ('X_train shape', (7510, 500))
# ('X_test shape', (832, 500))
# ('X_train shape', (7514, 500))
# ('X_test shape', (828, 500))
# ('X_train shape', (7516, 500))
# ('X_test shape', (826, 500))
# ('X_train shape', (7518, 500))
# ('X_test shape', (824, 500))
# ('X_train shape', (7521, 500))
# ('X_test shape', (821, 500))
# 600
# ('X_train shape', (7492, 600))
# ('X_test shape', (850, 600))
# ('X_train shape', (7496, 600))
# ('X_test shape', (846, 600))
# ('X_train shape', (7497, 600))
# ('X_test shape', (845, 600))
# ('X_train shape', (7506, 600))
# ('X_test shape', (836, 600))
# ('X_train shape', (7508, 600))
# ('X_test shape', (834, 600))
# ('X_train shape', (7510, 600))
# ('X_test shape', (832, 600))
# ('X_train shape', (7514, 600))
# ('X_test shape', (828, 600))
# ('X_train shape', (7516, 600))
# ('X_test shape', (826, 600))
# ('X_train shape', (7518, 600))
# ('X_test shape', (824, 600))
# ('X_train shape', (7521, 600))
# ('X_test shape', (821, 600))
# 700
# ('X_train shape', (7492, 700))
# ('X_test shape', (850, 700))
# ('X_train shape', (7496, 700))
# ('X_test shape', (846, 700))
# ('X_train shape', (7497, 700))
# ('X_test shape', (845, 700))
# ('X_train shape', (7506, 700))
# ('X_test shape', (836, 700))
# ('X_train shape', (7508, 700))
# ('X_test shape', (834, 700))
# ('X_train shape', (7510, 700))
# ('X_test shape', (832, 700))
# ('X_train shape', (7514, 700))
# ('X_test shape', (828, 700))
# ('X_train shape', (7516, 700))
# ('X_test shape', (826, 700))
# ('X_train shape', (7518, 700))
# ('X_test shape', (824, 700))
# ('X_train shape', (7521, 700))
# ('X_test shape', (821, 700))
# 800
# ('X_train shape', (7492, 800))
# ('X_test shape', (850, 800))
# ('X_train shape', (7496, 800))
# ('X_test shape', (846, 800))
# ('X_train shape', (7497, 800))
# ('X_test shape', (845, 800))
# ('X_train shape', (7506, 800))
# ('X_test shape', (836, 800))
# ('X_train shape', (7508, 800))
# ('X_test shape', (834, 800))
# ('X_train shape', (7510, 800))
# ('X_test shape', (832, 800))
# ('X_train shape', (7514, 800))
# ('X_test shape', (828, 800))
# ('X_train shape', (7516, 800))
# ('X_test shape', (826, 800))
# ('X_train shape', (7518, 800))
# ('X_test shape', (824, 800))
# ('X_train shape', (7521, 800))
# ('X_test shape', (821, 800))
# 900
# ('X_train shape', (7492, 900))
# ('X_test shape', (850, 900))
# ('X_train shape', (7496, 900))
# ('X_test shape', (846, 900))
# ('X_train shape', (7497, 900))
# ('X_test shape', (845, 900))
# ('X_train shape', (7506, 900))
# ('X_test shape', (836, 900))
# ('X_train shape', (7508, 900))
# ('X_test shape', (834, 900))
# ('X_train shape', (7510, 900))
# ('X_test shape', (832, 900))
# ('X_train shape', (7514, 900))
# ('X_test shape', (828, 900))
# ('X_train shape', (7516, 900))
# ('X_test shape', (826, 900))
# ('X_train shape', (7518, 900))
# ('X_test shape', (824, 900))
# ('X_train shape', (7521, 900))
# ('X_test shape', (821, 900))
# 1000
# ('X_train shape', (7492, 1000))
# ('X_test shape', (850, 1000))
# ('X_train shape', (7496, 1000))
# ('X_test shape', (846, 1000))
# ('X_train shape', (7497, 1000))
# ('X_test shape', (845, 1000))
# ('X_train shape', (7506, 1000))
# ('X_test shape', (836, 1000))
# ('X_train shape', (7508, 1000))
# ('X_test shape', (834, 1000))
# ('X_train shape', (7510, 1000))
# ('X_test shape', (832, 1000))
# ('X_train shape', (7514, 1000))
# ('X_test shape', (828, 1000))
# ('X_train shape', (7516, 1000))
# ('X_test shape', (826, 1000))
# ('X_train shape', (7518, 1000))
# ('X_test shape', (824, 1000))
# ('X_train shape', (7521, 1000))
# ('X_test shape', (821, 1000))
# 1100
# ('X_train shape', (7492, 1100))
# ('X_test shape', (850, 1100))
# ('X_train shape', (7496, 1100))
# ('X_test shape', (846, 1100))
# ('X_train shape', (7497, 1100))
# ('X_test shape', (845, 1100))
# ('X_train shape', (7506, 1100))
# ('X_test shape', (836, 1100))
# ('X_train shape', (7508, 1100))
# ('X_test shape', (834, 1100))
# ('X_train shape', (7510, 1100))
# ('X_test shape', (832, 1100))
# ('X_train shape', (7514, 1100))
# ('X_test shape', (828, 1100))
# ('X_train shape', (7516, 1100))
# ('X_test shape', (826, 1100))
# ('X_train shape', (7518, 1100))
# ('X_test shape', (824, 1100))
# ('X_train shape', (7521, 1100))
# ('X_test shape', (821, 1100))
# 1200
# ('X_train shape', (7492, 1200))
# ('X_test shape', (850, 1200))
# ('X_train shape', (7496, 1200))
# ('X_test shape', (846, 1200))
# ('X_train shape', (7497, 1200))
# ('X_test shape', (845, 1200))
# ('X_train shape', (7506, 1200))
# ('X_test shape', (836, 1200))
# ('X_train shape', (7508, 1200))
# ('X_test shape', (834, 1200))
# ('X_train shape', (7510, 1200))
# ('X_test shape', (832, 1200))
# ('X_train shape', (7514, 1200))
# ('X_test shape', (828, 1200))
# ('X_train shape', (7516, 1200))
# ('X_test shape', (826, 1200))
# ('X_train shape', (7518, 1200))
# ('X_test shape', (824, 1200))
# ('X_train shape', (7521, 1200))
# ('X_test shape', (821, 1200))
